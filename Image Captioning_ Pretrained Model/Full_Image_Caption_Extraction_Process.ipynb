# %%
# !pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 8.0 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 38.9 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 38.7 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.2 transformers-4.24.0

# %%
import os
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = "/content/gdrive/MyDrive/CoffeeImagesRawFINAL"

# %%
os.chdir(path)

# %%
# Using process generated by teammate Sanjay M to extend captioning to all images from our database

import torch
from transformers import VisionEncoderDecoderModel, ViTFeatureExtractor, AutoTokenizer
from PIL import Image

# %%
model = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
feature_extractor = ViTFeatureExtractor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
tokenizer = AutoTokenizer.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
# Out:
# Downloading:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/982M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/228 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/241 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/120 [00:00<?, ?B/s]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# %%
max_length = 16
num_beams = 4
gen_kwargs = {"max_length": max_length, "num_beams": num_beams}
def predict_step(image_paths):
  images = []
  captions = []
  for image_path in image_paths:
    i_image = Image.open(image_path)
    if i_image.mode != "RGB":
      i_image = i_image.convert(mode="RGB")

    images.append(i_image)
  pixel_values = feature_extractor(images=images, return_tensors="pt").pixel_values
  pixel_values = pixel_values.to(device)

  output_ids = model.generate(pixel_values, **gen_kwargs)

  preds = tokenizer.batch_decode(output_ids, skip_special_tokens=True)
  preds = [pred.strip() for pred in preds]
  return preds

# %%
import glob

# %%
folders = glob.glob("/content/gdrive/My Drive/CoffeeImagesRawFINAL/")
image_captions = []
for folder in folders:
  print("Looking for images in",folder)
  for f in glob.glob(folder+'*.jpg'):
    x=(predict_step([f]))
    print("Image:",f)
    print("Caption:",x)
    image_captions.append(x)
# Out:
# Looking for images in /content/gdrive/My Drive/CoffeeImagesRawFINAL/
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeaddict3.jpg
# Caption: ['a living room filled with furniture and a fire place']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeaddict2.jpg
# Caption: ['a building that has graffiti on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeaddict4.jpg
# Caption: ['a large building with a clock on the front of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeaddict5.jpg
# Caption: ['a skateboard with a knife sticking out of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeaddict9.jpg
# Caption: ['a large swimming pool in front of a large building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeaddict8.jpg
# Caption: ['a person holding a cup of coffee on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelovers8.jpg
# Caption: ['a person pouring a liquid into a blender']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelovers4.jpg
# Caption: ['a wooden table topped with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelovers7.jpg
# Caption: ['a painting of a fire hydrant with a cartoon character on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelovers5.jpg
# Caption: ['a large kitchen with a lot of counter space']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelovers3.jpg
# Caption: ['a person holding a wine glass in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelovers6.jpg
# Caption: ['a coffee mug sitting on top of a coffee table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelovers2.jpg
# Caption: ['a coffee cup sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelovers9.jpg
# Caption: ['a chocolate cupcake in a blender on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegram4.jpg
# Caption: ['a green and white building with a blue umbrella']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegram6.jpg
# Caption: ['a large building with a sign on the front of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegram3.jpg
# Caption: ['a person holding a cup in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegram5.jpg
# Caption: ['a store with a sign on the side of the building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegram1.jpg
# Caption: ['people are standing outside of a restaurant']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegram2.jpg
# Caption: ['a kitchen filled with furniture and a large window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegram9.jpg
# Caption: ['a cup of coffee sitting on top of a plant']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegram7.jpg
# Caption: ['a white plate topped with a bunch of cupcakes']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegram8.jpg
# Caption: ['a cup of coffee and a spoon on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeart2.jpg
# Caption: ['a kitchen with a stove, sink, and refrigerator']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeart1.jpg
# Caption: ['a bowl filled with a liquid on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeart6.jpg
# Caption: ['a woman in a pink dress holding a pink umbrella']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeart4.jpg
# Caption: ['a coffee cup sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeart9.jpg
# Caption: ['a woman holding an umbrella in front of her face']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeart3.jpg
# Caption: ['a person holding a cup of coffee in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeart8.jpg
# Caption: ['a dog drinking from a cup on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeart5.jpg
# Caption: ['a woman jumping in the air with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeart7.jpg
# Caption: ['a building with a large window on the side of the building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelife3.jpg
# Caption: ['a coffee cup sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelife2.jpg
# Caption: ['a person pouring a liquid into a blender']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelife1.jpg
# Caption: ['a table topped with bowls and bowls of various shapes and sizes']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelife4.jpg
# Caption: ['a large building with a large window on the side of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelife6.jpg
# Caption: ['a kitchen area with a table and chairs']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelife9.jpg
# Caption: ['a wooden table topped with a wooden cup and a wooden spoon']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelife5.jpg
# Caption: ['a plate of food on a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelife8.jpg
# Caption: ['a piece of cake sitting on a plate next to a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelife7.jpg
# Caption: ['a store front with a large window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebreak2.jpg
# Caption: ['a person holding a spoon in front of a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebreak1.jpg
# Caption: ['two chairs and a table in front of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebreak6.jpg
# Caption: ['a cake sitting on top of a table next to a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebreak8.jpg
# Caption: ['a table topped with plates filled with food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebreak9.jpg
# Caption: ['a cupcake with a flower in it sitting on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebreak3.jpg
# Caption: ['a cup of coffee next to a bowl of flowers']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebreak7.jpg
# Caption: ['a cup of coffee sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebreak5.jpg
# Caption: ['a woman is holding up a sign that says "birthday"']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebreak4.jpg
# Caption: ['a cup of coffee with a flower in it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeholic1.jpg
# Caption: ['a cupcake with sprinkles on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeholic2.jpg
# Caption: ['a room with a table, chairs, and tables in it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeholic6.jpg
# Caption: ['a man on a skateboard in front of a store']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeholic9.jpg
# Caption: ['a large building with a clock on the front of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeholic8.jpg
# Caption: ['a building with a large window on the side of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeholic7.jpg
# Caption: ['a woman sitting at a table with a cell phone']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeholic5.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeholic3.jpg
# Caption: ['a piece of cake that is on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeholic4.jpg
# Caption: ['a plate of food sitting on top of a counter']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeehouse3.jpg
# Caption: ['a living room with a clock on the wall']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeehouse1.jpg
# Caption: ['a restaurant kitchen with a large counter top and a large counter top']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeehouse2.jpg
# Caption: ['a store filled with lots of different types of items']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeehouse7.jpg
# Caption: ['a man sitting at a table in front of a restaurant']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeehouse5.jpg
# Caption: ['a kitchen with a stove and a window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeehouse4.jpg
# Caption: ['a large building with a large window on the side of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeehouse6.jpg
# Caption: ['a woman sitting at a table in a restaurant']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeehouse8.jpg
# Caption: ['a white house with a blue door and a white umbrella']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeehouse9.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeculture4.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeculture3.jpg
# Caption: ['a large white building with a bench in front of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeculture2.jpg
# Caption: ['a painting of a group of people dressed in medieval clothing']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeculture1.jpg
# Caption: ['a tray of food on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeculture5.jpg
# Caption: ['a church with a large clock on the front of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeculture6.jpg
# Caption: ['a garden area with a bench and a tree']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeculture9.jpg
# Caption: ['a wooden table topped with a bunch of cupcakes']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeculture8.jpg
# Caption: ['a bottle of wine sitting on top of a pile of grapes']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeculture7.jpg
# Caption: ['a table topped with a plate of food and a drink']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshots1.jpg
# Caption: ['a store front with a large window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshots3.jpg
# Caption: ['a man sitting at a table talking on a cell phone']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshots2.jpg
# Caption: ['two women sitting at a counter in a restaurant']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshots9.jpg
# Caption: ['a person pouring a liquid into a blender']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshots8.jpg
# Caption: ['a table topped with cakes filled with frosting']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshots7.jpg
# Caption: ['a piece of pizza sitting on top of a table next to a book']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshots6.jpg
# Caption: ['a coffee cup sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshots4.jpg
# Caption: ['a table topped with a plant and a bag']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshots5.jpg
# Caption: ['a person holding a cup of coffee next to a plate of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeedaily1.jpg
# Caption: ['a building that has a lot of stuff in it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeedaily4.jpg
# Caption: ['a cup of coffee and a donut on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeedaily3.jpg
# Caption: ['a church with a large clock on the front of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeedaily6.jpg
# Caption: ['a wooden bench sitting in front of a tree']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeedaily5.jpg
# Caption: ['a living room filled with furniture and a large window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeedaily7.jpg
# Caption: ['a bowl filled with a mixture of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeedaily2.jpg
# Caption: ['a large room with a lot of tables and chairs']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeedaily9.jpg
# Caption: ['a sign with a bunch of numbers on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeevibes1.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeevibes2.jpg
# Caption: ['a bowl filled with a mixture of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeevibes3.jpg
# Caption: ['a large building with a large window in front of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeevibes6.jpg
# Caption: ['a black and white photo of a black and white sign']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeevibes9.jpg
# Caption: ['a cup of coffee sitting on top of a table next to a bag of']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeevibes8.jpg
# Caption: ['a table that has a bunch of plates of food on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeevibes5.jpg
# Caption: ['a kitchen area with a table and chairs']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeevibes7.jpg
# Caption: ['a room with a table and chairs in it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeevibes4.jpg
# Caption: ['a man working on a machine inside of a garage']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeesesh2.jpg
# Caption: ['a person pouring a liquid into a blender']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeesesh6.jpg
# Caption: ['a cake sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeesesh8.jpg
# Caption: ['a table topped with a plate of food and a vase of flowers']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeesesh3.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeesesh5.jpg
# Caption: ['a house with a fence and some trees']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeesesh4.jpg
# Caption: ['a coffee cup sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeesesh1.jpg
# Caption: ['a statue of a woman standing in front of a fire hydrant']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeesesh7.jpg
# Caption: ['a coffee cup sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeesesh9.jpg
# Caption: ['a woman holding a child on top of a couch']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeprops1.jpg
# Caption: ['a cup of coffee sitting on top of a counter']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeprops4.jpg
# Caption: ['a coffee cup with a coffee maker on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeprops7.jpg
# Caption: ['a cup of coffee and a plate of food on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeprops6.jpg
# Caption: ['a kitchen with a table, chairs, and a refrigerator']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeprops2.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeprops3.jpg
# Caption: ['a computer desk with a monitor and keyboard']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeprops8.jpg
# Caption: ['a kitchen with a table and chairs in it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeprops5.jpg
# Caption: ['a person in a kitchen preparing food on a stove']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeprops9.jpg
# Caption: ['a plate of food on a table with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeoftheday4.jpg
# Caption: ['a large white bathroom with a large window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeoftheday3.jpg
# Caption: ['a coffee cup sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeoftheday2.jpg
# Caption: ['a kitchen with a stove and a window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeoftheday5.jpg
# Caption: ['a chocolate cupcake in a blender on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeoftheday1.jpg
# Caption: ['a man sitting on a bench next to a street sign']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeoftheday6.jpg
# Caption: ['a store filled with lots of different types of items']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeoftheday7.jpg
# Caption: ['a large building with a large window on the side of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeoftheday8.jpg
# Caption: ['a kitchen with a table and chairs in it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeoftheday9.jpg
# Caption: ['a bench in front of a building with trees']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecoffeecoffee3.jpg
# Caption: ['a coffee cup sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecoffeecoffee4.jpg
# Caption: ['a kitchen filled with lots of counter space']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecoffeecoffee1.jpg
# Caption: ['a kitchen with a table and chairs in it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecoffeecoffee8.jpg
# Caption: ['a cup of coffee with a piece of cake on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecoffeecoffee5.jpg
# Caption: ['a person holding a banana in front of a window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecoffeecoffee2.jpg
# Caption: ['a person holding a piece of cake on top of a pillow']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecoffeecoffee6.jpg
# Caption: ['a cup of coffee on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecoffeecoffee7.jpg
# Caption: ['a table topped with a cup of coffee next to a bunch of bananas']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecoffeecoffee9.jpg
# Caption: ['a variety of fruits and vegetables on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebrewing3.jpg
# Caption: ['a vase with flowers sitting on a table next to a coffee cup']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebrewing4.jpg
# Caption: ['a wooden table topped with a coffee mug and a vase']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebrewing1.jpg
# Caption: ['a pair of scissors sitting on top of a sink']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebrewing5.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebrewing6.jpg
# Caption: ['a cupcake sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebrewing2.jpg
# Caption: ['an alarm clock sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebrewing7.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebrewing8.jpg
# Caption: ['a wooden table with a piece of wood on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebrewing9.jpg
# Caption: ['a person holding a piece of chocolate cake']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebar1.jpg
# Caption: ['a kitchen counter with a coffee pot and a microwave']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebar2.jpg
# Caption: ['a kitchen with a shelf filled with dishes']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebar3.jpg
# Caption: ['a kitchen filled with lots of counter space and lots of cabinets']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebar4.jpg
# Caption: ['a kitchen area with a stove and a shelf']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebar5.jpg
# Caption: ['a coffee maker with a coffee cup on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebar9.jpg
# Caption: ['a person holding a knife and a cup in front of a cat']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebar6.jpg
# Caption: ['a person in a kitchen working on a machine']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebar7.jpg
# Caption: ['a white counter top with a vase of flowers on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebar8.jpg
# Caption: ['a large white building with a large window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemug1.jpg
# Caption: ['a vase with flowers on a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemug4.jpg
# Caption: ['a green coffee cup sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemug5.jpg
# Caption: ['a person holding a cup with a teddy bear on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemug6.jpg
# Caption: ['a table topped with bowls filled with cupcakes']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemug8.jpg
# Caption: ['a table topped with vases filled with flowers']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemug7.jpg
# Caption: ['a cup of tea and a spoon on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemug2.jpg
# Caption: ['a piece of paper that is on top of a pillow']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemug3.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemug9.jpg
# Caption: ['a coffee cup with a picture of a bear on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetaste1.jpg
# Caption: ['a dog laying on top of a blanket on a bed']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetaste2.jpg
# Caption: ['an old black and white photo of a rotten substance']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetaste5.jpg
# Caption: ['a black and white photo of a piece of cake']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetaste4.jpg
# Caption: ['a wooden table topped with bowls of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetaste3.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetaste6.jpg
# Caption: ['a cup of coffee is being poured into a coffee mug']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetaste9.jpg
# Caption: ['a box filled with lots of chocolate frosted donuts']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetaste8.jpg
# Caption: ['a person holding a cup in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetaste7.jpg
# Caption: ['a wooden table with a vase of flowers on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroaster1.jpg
# Caption: ['a piece of paper with a picture of a train on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroaster6.jpg
# Caption: ['a person pouring a liquid into a blender']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroaster4.jpg
# Caption: ['a table topped with lots of different types of appliances']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroaster5.jpg
# Caption: ['a traffic light with a street sign on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroaster2.jpg
# Caption: ['a number of wine glasses on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroaster3.jpg
# Caption: ['a motorcycle parked in front of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroaster9.jpg
# Caption: ['a machine that is inside of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroaster7.jpg
# Caption: ['a table topped with a bag of doughnuts']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroaster8.jpg
# Caption: ['a man standing in front of a pot on a stove']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegeek3.jpg
# Caption: ['a living room filled with lots of furniture']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegeek5.jpg
# Caption: ['a person sitting on the floor with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegeek6.jpg
# Caption: ['a painting of a woman holding a sign']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegeek2.jpg
# Caption: ['a store front with a window and a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegeek1.jpg
# Caption: ['a coffee maker on a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegeek4.jpg
# Caption: ['a pot of food on a stove top']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegeek8.jpg
# Caption: ['a sign that is on the side of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegeek7.jpg
# Caption: ['a muffin tray filled with muffins on top of a stove']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeegeek9.jpg
# Caption: ['a person pouring a liquid into a blender']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeephotography4.jpg
# Caption: ['a cup of coffee is sitting on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeephotography6.jpg
# Caption: ['a cup of tea in a vase on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeephotography3.jpg
# Caption: ['a cup of tea with a flower in it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeephotography5.jpg
# Caption: ['a bowl of soup sitting on top of a white table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeephotography1.jpg
# Caption: ['a piece of cake sitting on top of a toilet']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeephotography2.jpg
# Caption: ['a table topped with a bowl of food and a cell phone']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeephotography7.jpg
# Caption: ['a man and a woman playing a game of ping pong']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeephotography9.jpg
# Caption: ['a table topped with a plate of food and a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeephotography8.jpg
# Caption: ['a woman in a pink dress sitting on a bed']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecup4.jpg
# Caption: ['a glass vase with a flower in it on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecup1.jpg
# Caption: ['a kitchen with a stove and a window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecup5.jpg
# Caption: ['a stuffed animal with a cartoon character on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecup2.jpg
# Caption: ['a bench in front of a building with trees']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecup3.jpg
# Caption: ['a blue vase sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecup8.jpg
# Caption: ['a blue and white plate with a flower on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecup6.jpg
# Caption: ['a white cup sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecup7.jpg
# Caption: ['a person holding a cup of coffee in front of a crowd of people']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecup9.jpg
# Caption: ['a white cupcake sitting on top of a pile of leaves']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebeans3.jpg
# Caption: ['a cup of coffee and a plate of food on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebeans4.jpg
# Caption: ['a piece of cake that is on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebeans5.jpg
# Caption: ['a pot of food on a stove top']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebeans2.jpg
# Caption: ['a field filled with lots of green plants']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebeans6.jpg
# Caption: ['a cupcake with sprinkles on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebeans1.jpg
# Caption: ['a pile of brown and white stuff sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebeans9.jpg
# Caption: ['a coffee cup sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebeans7.jpg
# Caption: ['a collage of photographs showing different types of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeebeans8.jpg
# Caption: ['a woman is looking at flowers in a vase']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeequotes7.jpg
# Caption: ['a cup of coffee sitting next to a picture of a cartoon character']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeequotes5.jpg
# Caption: ['a coffee cup sitting on top of a book']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeequotes2.jpg
# Caption: ['a person holding a cup of coffee next to a stuffed animal']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeequotes3.jpg
# Caption: ['a black and white photo of a sign on a white wall']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeequotes4.jpg
# Caption: ['a collage of photos showing different types of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeequotes8.jpg
# Caption: ['a coffee cup sitting on top of a book']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeequotes6.jpg
# Caption: ['a dog laying on a bed next to a book']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeequotes1.jpg
# Caption: ['a coffee cup with a picture of a man on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeequotes9.jpg
# Caption: ['a coffee cup sitting on top of a white paper']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeepeople4.jpg
# Caption: ['a coffee cup sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeepeople3.jpg
# Caption: ['a person holding a spoon in front of a cup']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeepeople1.jpg
# Caption: ['a cup of coffee on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeepeople2.jpg
# Caption: ['a traffic light with a street sign on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeepeople5.jpg
# Caption: ['a kitchen with a large counter top and a large clock on the wall']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeepeople8.jpg
# Caption: ['a statue of a woman standing in front of a fire hydrant']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeepeople6.jpg
# Caption: ['a plate of food on a table with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeepeople9.jpg
# Caption: ['a cup of coffee sitting on top of a white plate']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeepeople7.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandseasons2.jpg
# Caption: ['a wooden table topped with plates of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandseasons1.jpg
# Caption: ['a cup of coffee sitting on top of a blanket']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandseasons6.jpg
# Caption: ['a coffee cup sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandseasons9.jpg
# Caption: ['a table topped with a cup of coffee and a book']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandseasons7.jpg
# Caption: ['a person holding a drink in front of a car']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandseasons4.jpg
# Caption: ['a book and a cup of coffee on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandseasons8.jpg
# Caption: ['a person holding a donut in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandseasons3.jpg
# Caption: ['a person holding a spoon in front of a bowl of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandseasons5.jpg
# Caption: ['a person holding a piece of toast in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroasting2.jpg
# Caption: ['a person is spraying something on a fire hydrant']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroasting1.jpg
# Caption: ['a sign that is on a wall']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroasting8.jpg
# Caption: ['a man holding a knife in front of a machine']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroasting4.jpg
# Caption: ['a vase filled with yellow flowers on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroasting7.jpg
# Caption: ['a cup of coffee and a plate of food on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroasting5.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroasting9.jpg
# Caption: ['a clock hanging from the side of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroasting3.jpg
# Caption: ['a person holding a spoon in front of a bowl of beans']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroasting6.jpg
# Caption: ['a chocolate frosted cupcake sitting on top of a white plate']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeestory3.jpg
# Caption: ['a coffee cup sitting on top of a table next to a flower pot']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeestory2.jpg
# Caption: ['a cup of coffee next to a piece of cake']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeestory1.jpg
# Caption: ['a person holding a cup of coffee in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeestory4.jpg
# Caption: ['a cup of coffee and a cup of tea on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeestory8.jpg
# Caption: ['a cup of coffee sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeestory7.jpg
# Caption: ['a table topped with a cup of coffee next to a vase filled with']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeestory9.jpg
# Caption: ['a man standing next to a woman holding an umbrella']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeestory6.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeestory5.jpg
# Caption: ['a piece of bread sitting on top of a paper plate']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroastery2.jpg
# Caption: ['a box with a bunch of stickers on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroastery1.jpg
# Caption: ['a motorcycle parked in front of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroastery3.jpg
# Caption: ['a man standing outside of a building looking at a tree']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroastery5.jpg
# Caption: ['a piece of wood sitting on top of a pile of rocks']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroastery4.jpg
# Caption: ['a piece of cake sitting on top of a white plate']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroastery7.jpg
# Caption: ['a large metal door on the side of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroastery8.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroastery9.jpg
# Caption: ['a wooden bowl filled with lots of different types of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeroastery6.jpg
# Caption: ['a large room with a large clock on the wall']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecorner1.jpg
# Caption: ['a painting of a man in a suit']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecorner5.jpg
# Caption: ['a kitchen area with a table and chairs']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecorner2.jpg
# Caption: ['a painting of a horse on a table in a room']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecorner7.jpg
# Caption: ['a plate of food on a table with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecorner6.jpg
# Caption: ['a vase filled with flowers sitting on a counter top']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecorner4.jpg
# Caption: ['a table topped with lots of different types of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecorner3.jpg
# Caption: ['a kitchen with a stove top oven and a counter top']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecorner9.jpg
# Caption: ['a kitchen counter topped with a blender and other items']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecorner8.jpg
# Caption: ['a kitchen with a stove top oven and cabinets']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeislove2.jpg
# Caption: ['a cake with a picture of a dog on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeislove1.jpg
# Caption: ['a plate of food on a table with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeislove7.jpg
# Caption: ['a person holding a spoon in front of a window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeislove8.jpg
# Caption: ['a cup of coffee sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeislove9.jpg
# Caption: ['people riding on a train on a track']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeislove3.jpg
# Caption: ['a person holding a glass of orange juice on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeislove4.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeislove6.jpg
# Caption: ['a cup of coffee sitting on top of a beach']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeislove5.jpg
# Caption: ['a coffee cup sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee_inst1.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee_inst4.jpg
# Caption: ['a clock hanging from the side of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee_inst6.jpg
# Caption: ['a coffee cup sitting on top of a coffee table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee_inst7.jpg
# Caption: ['a cupcake sitting on top of a pile of leaves']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee_inst2.jpg
# Caption: ['a laptop computer sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee_inst5.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee_inst9.jpg
# Caption: ['a person holding a cup of coffee next to a piece of cake']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee_inst3.jpg
# Caption: ['a blender filled with liquid on top of a counter']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee_inst8.jpg
# Caption: ['a cat sitting on top of a blanket next to a book']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemachine7.jpg
# Caption: ['a large white building with a large window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemachine5.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemachine4.jpg
# Caption: ['a sign on a wall with a bunch of stickers on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemachine6.jpg
# Caption: ['a plate of food on a table with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemachine1.jpg
# Caption: ['a man is holding a cup of coffee in front of a stove']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemachine2.jpg
# Caption: ['a machine that has a lot of tools on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemachine3.jpg
# Caption: ['a stove top oven sitting on top of a counter']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemachine9.jpg
# Caption: ['a machine that has a lot of stuff on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemachine8.jpg
# Caption: ['a machine that is sitting on a counter']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemaker1.jpg
# Caption: ['a table topped with a laptop computer and other items']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemaker2.jpg
# Caption: ['a kitchen with a shelf filled with dishes']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemaker7.jpg
# Caption: ['a cup of coffee sitting on top of a machine']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemaker3.jpg
# Caption: ['a cup of coffee sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemaker5.jpg
# Caption: ['a plate of food on a table with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemaker6.jpg
# Caption: ['a vase filled with flowers sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemaker4.jpg
# Caption: ['a kitchen filled with lots of pots and pans']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemaker9.jpg
# Caption: ['a kitchen filled with lots of counter space and lots of cabinets']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeemaker8.jpg
# Caption: ['a person is holding a red and white fire hydrant']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshopcorners3.jpg
# Caption: ['a patio area with chairs, tables, and umbrellas']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshopcorners4.jpg
# Caption: ['a car is parked in front of a tall building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshopcorners1.jpg
# Caption: ['a living room filled with furniture and plants']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshopcorners6.jpg
# Caption: ['a large building with a large window on the side of the building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshopcorners5.jpg
# Caption: ['a room with a lot of plants in it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshopcorners2.jpg
# Caption: ['a bathroom with a toilet, sink, and bookshelf']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshopcorners7.jpg
# Caption: ['a table topped with plates of food and drinks']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshopcorners8.jpg
# Caption: ['a woman is cutting a cake on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshopcorners9.jpg
# Caption: ['a building with a large window on the side of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeplease8.jpg
# Caption: ['a cup of coffee sitting on top of a rock']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeplease7.jpg
# Caption: ['a cup of coffee sitting on top of a table next to a banana']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeplease2.jpg
# Caption: ['a coffee cup sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeplease1.jpg
# Caption: ['a person holding a cup of coffee in front of a store']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeplease4.jpg
# Caption: ['a cup of coffee sitting on a table next to a pool of water']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeplease5.jpg
# Caption: ['two cupcakes sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeplease3.jpg
# Caption: ['a table topped with cakes filled with frosting']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeplease6.jpg
# Caption: ['a coffee cup with a picture of a cat on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeplease9.jpg
# Caption: ['a birthday cake with a picture of a bear on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandbooks2.jpg
# Caption: ['a table topped with lots of different types of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandbooks1.jpg
# Caption: ['a book with a clock on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandbooks7.jpg
# Caption: ['a person sitting on the ground reading a book']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandbooks6.jpg
# Caption: ['a book is sitting on top of a coffee cup']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandbooks8.jpg
# Caption: ['a book that is on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandbooks4.jpg
# Caption: ['a white plate topped with a bunch of different types of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandbooks3.jpg
# Caption: ['a person laying on a bed with a clock']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandbooks5.jpg
# Caption: ['a table topped with plates of food and a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeandbooks9.jpg
# Caption: ['a laptop computer sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecommunity2.jpg
# Caption: ['two cupcakes sitting next to each other on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecommunity1.jpg
# Caption: ['a series of photos showing different types of drinks']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecommunity9.jpg
# Caption: ['a white candle sitting on top of a table next to a book']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecommunity8.jpg
# Caption: ['a pile of apples sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecommunity7.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecommunity6.jpg
# Caption: ['a kitchen filled with pots and pans']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecommunity4.jpg
# Caption: ['a woman holding a cup of coffee in front of a glass']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecommunity3.jpg
# Caption: ['a painting of a man holding a wine bottle']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeecommunity5.jpg
# Caption: ['a bowl of ice cream and a spoon']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeblogger1.jpg
# Caption: ['people sitting around a table in a park']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeblogger3.jpg
# Caption: ['a cup of coffee sitting on top of a white plate']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeblogger2.jpg
# Caption: ['a motorcycle parked on the side of a road']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeblogger8.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeblogger6.jpg
# Caption: ['a pair of scissors sitting on top of a sink']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeblogger5.jpg
# Caption: ['a traffic light with a street sign on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeblogger9.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeblogger4.jpg
# Caption: ['a coffee cup sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeblogger7.jpg
# Caption: ['a woman is cutting a cake on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelifestyle5.jpg
# Caption: ['a sign with a picture of a dog on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelifestyle3.jpg
# Caption: ['a computer monitor sitting on top of a desk']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelifestyle6.jpg
# Caption: ['a painting of a cat with a bow on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelifestyle4.jpg
# Caption: ['a stove top oven sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelifestyle1.jpg
# ...
# Caption: ['a person reading a newspaper on a city street']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefliicks2.jpg
# Caption: ['a room with a lot of plants in it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefliicks9.jpg
# Caption: ['a person holding a spoon and a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefliicks5.jpg
# Caption: ['a plate of food on a table with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefliicks8.jpg
# Caption: ['a person sitting at a table with a plate of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefliicks7.jpg
# Caption: ['a table topped with plates of food and drinks']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefliicks6.jpg
# Caption: ['a cup of coffee sitting on a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefirst1.jpg
# Caption: ['a coffee cup sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefirst4.jpg
# Caption: ['a person holding a cup with a coffee cup on top of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefirst3.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefirst5.jpg
# Caption: ['a man standing in front of a counter in a kitchen']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefirst7.jpg
# Caption: ['a cup of coffee sitting on a table next to a plant']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefirst2.jpg
# Caption: ['a cupcake with a picture of a dog on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefirst6.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefirst8.jpg
# Caption: ['a coffee cup with a picture of a cat on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefirst9.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefeature1.jpg
# Caption: ['a cup of coffee and a pastry on a wooden bench']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefeature2.jpg
# Caption: ['a restaurant with tables and chairs in the middle of the room']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefeature8.jpg
# Caption: ['a large wooden structure with a bench under it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefeature7.jpg
# Caption: ['a train station with a train on the tracks']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefeature5.jpg
# Caption: ['a large white boat sitting in front of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefeature3.jpg
# Caption: ['a living room filled with furniture and a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefeature6.jpg
# Caption: ['a wooden table with a pot of tea and a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefeature4.jpg
# Caption: ['a table with a plate of food and a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefeature9.jpg
# Caption: ['a brick building with a fire hydrant in front of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefarm4.jpg
# Caption: ['a sign that is on the side of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefarm3.jpg
# Caption: ['a person holding a bunch of different types of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefarm6.jpg
# Caption: ['a tree filled with lots of green apples']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefarm1.jpg
# Caption: ['a car driving down a road next to a forest']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefarm2.jpg
# Caption: ['a field filled with lots of green plants']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefarm5.jpg
# Caption: ['a tree filled with lots of green apples']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefarm7.jpg
# Caption: ['a vase filled with flowers on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefarm9.jpg
# Caption: ['a large bowl filled with lots of red apples']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforlife1.jpg
# Caption: ['a person holding a cup of coffee next to a doughnut']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforlife4.jpg
# Caption: ['a cupcake sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforlife8.jpg
# Caption: ['a refrigerator filled with lots of different types of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforlife5.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforlife2.jpg
# Caption: ['a large piece of chocolate cake sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforlife6.jpg
# Caption: ['a bowl filled with lots of brown stuff on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforlife7.jpg
# Caption: ['a person is using a blender on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforlife3.jpg
# Caption: ['a large piece of chocolate cake sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforlife9.jpg
# Caption: ['a fire hydrant sitting in front of a church']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefreak2.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefreak1.jpg
# Caption: ['a plate of breakfast food and a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefreak3.jpg
# Caption: ['a person holding a cup in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefreak9.jpg
# Caption: ['a sign with a picture of a dog on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefreak7.jpg
# Caption: ['a person holding a sign on a street']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefreak4.jpg
# Caption: ['a person holding a cup of coffee next to a doughnut']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefreak8.jpg
# Caption: ['a plate of food on a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefreak6.jpg
# Caption: ['a piece of cake and a cup of coffee on a plate']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefanatic3.jpg
# Caption: ['a woman sitting at a table with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefanatic2.jpg
# Caption: ['a pot of food on a stove top']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefanatic5.jpg
# Caption: ['a cupcake sitting on top of a counter top']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefanatic6.jpg
# Caption: ['a person holding a cup in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefanatic4.jpg
# Caption: ['a woman sitting at a table with a plate of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefanatic1.jpg
# Caption: ['a man holding a cell phone in his hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefanatic9.jpg
# Caption: ['a pair of scissors sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefanatic8.jpg
# Caption: ['a cup of coffee sitting on top of a white plate']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefanatic7.jpg
# Caption: ['a woman and a man in a room']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefacts4.jpg
# Caption: ['a blue and white plate with a blue and white bird on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefacts2.jpg
# Caption: ['a black and white photo of a black and white sign']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefacts1.jpg
# Caption: ['a sign that is on the side of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefacts3.jpg
# Caption: ['a person sitting at a table with a plate of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefacts8.jpg
# Caption: ['a coffee maker sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefacts6.jpg
# Caption: ['a man sitting at a table with a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefacts5.jpg
# Caption: ['a collage of photos showing different types of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefacts7.jpg
# Caption: ['a collage of images of a person on a computer']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefacts9.jpg
# Caption: ['a painting of a coffee cup with a picture of a dog on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefilter6.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefilter7.jpg
# Caption: ['a white bowl filled with lots of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefilter5.jpg
# Caption: ['a painting of a cat sitting on top of a stove']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefilter3.jpg
# Caption: ['a painting of a person holding a cell phone']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefilter1.jpg
# Caption: ['a bowl filled with donuts on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefilter4.jpg
# Caption: ['a painting of a group of animals on a wall']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefilter2.jpg
# Caption: ['a glass vase filled with liquid sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefilter9.jpg
# Caption: ['a number of vases on a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeefilter8.jpg
# Caption: ['a box sitting on top of a counter top']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforever3.jpg
# Caption: ['a person holding a green drink in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforever4.jpg
# Caption: ['a painting of a statue of a man holding a cup']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforever2.jpg
# Caption: ['a coffee mug sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforever6.jpg
# Caption: ['a green vase sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforever5.jpg
# Caption: ['a tree filled with lots of leaves on top of a building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforever1.jpg
# Caption: ['a person holding a cup with a cartoon character on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforever7.jpg
# Caption: ['a piece of cake on a plate next to a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforever9.jpg
# Caption: ['a bike parked in front of a store']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeforever8.jpg
# Caption: ['a table topped with a piece of fruit and a knife']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee1.jpg
# Caption: ['a man and a woman looking at a glass of wine']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee6.jpg
# Caption: ['a piece of cake that is on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee3.jpg
# Caption: ['a piece of cake sitting on top of a white plate']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee2.jpg
# Caption: ['a person holding a cup of coffee']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee5.jpg
# Caption: ['people sitting at a table in front of a sunset']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee4.jpg
# Caption: ['a person holding a cup of coffee in their hand']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee8.jpg
# Caption: ['a sandwich and a cup of coffee on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee7.jpg
# Caption: ['a cup of coffee sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffee9.jpg
# Caption: ['a wooden table topped with bowls of food']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetime1.jpg
# Caption: ['a kitchen filled with furniture and a large window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetime2.jpg
# Caption: ['a large swimming pool in front of a large building']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetime3.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetime9.jpg
# Caption: ['a woman standing in a kitchen holding a cup']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetime5.jpg
# Caption: ['an outdoor dining area with tables, chairs and umbrellas']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetime7.jpg
# Caption: ['a garden area with a bench and a tree']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetime6.jpg
# Caption: ['a cup of coffee and a plate of cake on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetime8.jpg
# Caption: ['a cup of coffee sitting on top of a wooden table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeetime4.jpg
# Caption: ['a table topped with bowls of different types of fruit']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelover2.jpg
# Caption: ['a kitchen filled with furniture and a large window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelover3.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelover5.jpg
# Caption: ['a close up of a picture of a sign']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelover4.jpg
# Caption: ['a plate with two cakes and a cupcake on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelover1.jpg
# Caption: ['a table topped with a candy bar and a box of donuts']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelover6.jpg
# Caption: ['a coffee cup with a picture of a horse on it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelover7.jpg
# Caption: ['a cup of coffee and a plate of food on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelover9.jpg
# Caption: ['a garden area with a bench and a tree']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeelover8.jpg
# Caption: ['a kitchen with a stove top oven and a sink']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshop4.jpg
# Caption: ['a restaurant with a sign on the front of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshop2.jpg
# Caption: ['a dining room table with a lamp and a window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshop3.jpg
# Caption: ['a bottle of wine sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshop5.jpg
# Caption: ['a cup of coffee and a doughnut on a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshop1.jpg
# Caption: ['a large white building with a large window']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshop9.jpg
# Caption: ['a kitchen with a stove, sink, and refrigerator']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshop8.jpg
# Caption: ['a glass of orange juice sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshop6.jpg
# Caption: ['a brick building with a clock on the side of it']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeshop7.jpg
# Caption: ['a woman holding a child on top of a couch']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeaddict6.jpg
# Caption: ['a cup of coffee sitting on top of a table']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeaddict7.jpg
# Caption: ['a man standing in the middle of a lake with a camera']
# Image: /content/gdrive/My Drive/CoffeeImagesRawFINAL/coffeeaddict1.jpg
# Caption: ['a patio area with a bench and a walkway']

# %%
image_captions
# Out:
# [['a living room filled with furniture and a fire place'],
#  ['a building that has graffiti on it'],
#  ['a large building with a clock on the front of it'],
#  ['a skateboard with a knife sticking out of it'],
#  ['a large swimming pool in front of a large building'],
#  ['a person holding a cup of coffee on top of a table'],
#  ['a person pouring a liquid into a blender'],
#  ['a wooden table topped with a cup of coffee'],
#  ['a painting of a fire hydrant with a cartoon character on it'],
#  ['a large kitchen with a lot of counter space'],
#  ['a person holding a wine glass in their hand'],
#  ['a coffee mug sitting on top of a coffee table'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a chocolate cupcake in a blender on a table'],
#  ['a green and white building with a blue umbrella'],
#  ['a large building with a sign on the front of it'],
#  ['a person holding a cup in their hand'],
#  ['a store with a sign on the side of the building'],
#  ['people are standing outside of a restaurant'],
#  ['a kitchen filled with furniture and a large window'],
#  ['a cup of coffee sitting on top of a plant'],
#  ['a white plate topped with a bunch of cupcakes'],
#  ['a cup of coffee and a spoon on a table'],
#  ['a kitchen with a stove, sink, and refrigerator'],
#  ['a bowl filled with a liquid on top of a table'],
#  ['a woman in a pink dress holding a pink umbrella'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a woman holding an umbrella in front of her face'],
#  ['a person holding a cup of coffee in their hand'],
#  ['a dog drinking from a cup on top of a wooden table'],
#  ['a woman jumping in the air with a cup of coffee'],
#  ['a building with a large window on the side of the building'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a person pouring a liquid into a blender'],
#  ['a table topped with bowls and bowls of various shapes and sizes'],
#  ['a large building with a large window on the side of it'],
#  ['a kitchen area with a table and chairs'],
#  ['a wooden table topped with a wooden cup and a wooden spoon'],
#  ['a plate of food on a wooden table'],
#  ['a piece of cake sitting on a plate next to a cup of coffee'],
#  ['a store front with a large window'],
#  ['a person holding a spoon in front of a cup of coffee'],
#  ['two chairs and a table in front of a building'],
#  ['a cake sitting on top of a table next to a cup of coffee'],
#  ['a table topped with plates filled with food'],
#  ['a cupcake with a flower in it sitting on a table'],
#  ['a cup of coffee next to a bowl of flowers'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a woman is holding up a sign that says "birthday"'],
#  ['a cup of coffee with a flower in it'],
#  ['a cupcake with sprinkles on top of it'],
#  ['a room with a table, chairs, and tables in it'],
#  ['a man on a skateboard in front of a store'],
#  ['a large building with a clock on the front of it'],
#  ['a building with a large window on the side of it'],
#  ['a woman sitting at a table with a cell phone'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a piece of cake that is on a table'],
#  ['a plate of food sitting on top of a counter'],
#  ['a living room with a clock on the wall'],
#  ['a restaurant kitchen with a large counter top and a large counter top'],
#  ['a store filled with lots of different types of items'],
#  ['a man sitting at a table in front of a restaurant'],
#  ['a kitchen with a stove and a window'],
#  ['a large building with a large window on the side of it'],
#  ['a woman sitting at a table in a restaurant'],
#  ['a white house with a blue door and a white umbrella'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a large white building with a bench in front of it'],
#  ['a painting of a group of people dressed in medieval clothing'],
#  ['a tray of food on a table'],
#  ['a church with a large clock on the front of it'],
#  ['a garden area with a bench and a tree'],
#  ['a wooden table topped with a bunch of cupcakes'],
#  ['a bottle of wine sitting on top of a pile of grapes'],
#  ['a table topped with a plate of food and a drink'],
#  ['a store front with a large window'],
#  ['a man sitting at a table talking on a cell phone'],
#  ['two women sitting at a counter in a restaurant'],
#  ['a person pouring a liquid into a blender'],
#  ['a table topped with cakes filled with frosting'],
#  ['a piece of pizza sitting on top of a table next to a book'],
#  ['a coffee cup sitting on top of a table'],
#  ['a table topped with a plant and a bag'],
#  ['a person holding a cup of coffee next to a plate of food'],
#  ['a building that has a lot of stuff in it'],
#  ['a cup of coffee and a donut on a table'],
#  ['a church with a large clock on the front of it'],
#  ['a wooden bench sitting in front of a tree'],
#  ['a living room filled with furniture and a large window'],
#  ['a bowl filled with a mixture of food'],
#  ['a large room with a lot of tables and chairs'],
#  ['a sign with a bunch of numbers on it'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a bowl filled with a mixture of food'],
#  ['a large building with a large window in front of it'],
#  ['a black and white photo of a black and white sign'],
#  ['a cup of coffee sitting on top of a table next to a bag of'],
#  ['a table that has a bunch of plates of food on it'],
#  ['a kitchen area with a table and chairs'],
#  ['a room with a table and chairs in it'],
#  ['a man working on a machine inside of a garage'],
#  ['a person pouring a liquid into a blender'],
#  ['a cake sitting on top of a wooden table'],
#  ['a table topped with a plate of food and a vase of flowers'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a house with a fence and some trees'],
#  ['a coffee cup sitting on top of a table'],
#  ['a statue of a woman standing in front of a fire hydrant'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a woman holding a child on top of a couch'],
#  ['a cup of coffee sitting on top of a counter'],
#  ['a coffee cup with a coffee maker on top of it'],
#  ['a cup of coffee and a plate of food on a table'],
#  ['a kitchen with a table, chairs, and a refrigerator'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a computer desk with a monitor and keyboard'],
#  ['a kitchen with a table and chairs in it'],
#  ['a person in a kitchen preparing food on a stove'],
#  ['a plate of food on a table with a cup of coffee'],
#  ['a large white bathroom with a large window'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a kitchen with a stove and a window'],
#  ['a chocolate cupcake in a blender on a table'],
#  ['a man sitting on a bench next to a street sign'],
#  ['a store filled with lots of different types of items'],
#  ['a large building with a large window on the side of it'],
#  ['a kitchen with a table and chairs in it'],
#  ['a bench in front of a building with trees'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a kitchen filled with lots of counter space'],
#  ['a kitchen with a table and chairs in it'],
#  ['a cup of coffee with a piece of cake on it'],
#  ['a person holding a banana in front of a window'],
#  ['a person holding a piece of cake on top of a pillow'],
#  ['a cup of coffee on top of a wooden table'],
#  ['a table topped with a cup of coffee next to a bunch of bananas'],
#  ['a variety of fruits and vegetables on a table'],
#  ['a vase with flowers sitting on a table next to a coffee cup'],
#  ['a wooden table topped with a coffee mug and a vase'],
#  ['a pair of scissors sitting on top of a sink'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a cupcake sitting on top of a wooden table'],
#  ['an alarm clock sitting on top of a table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a wooden table with a piece of wood on top of it'],
#  ['a person holding a piece of chocolate cake'],
#  ['a kitchen counter with a coffee pot and a microwave'],
#  ['a kitchen with a shelf filled with dishes'],
#  ['a kitchen filled with lots of counter space and lots of cabinets'],
#  ['a kitchen area with a stove and a shelf'],
#  ['a coffee maker with a coffee cup on top of it'],
#  ['a person holding a knife and a cup in front of a cat'],
#  ['a person in a kitchen working on a machine'],
#  ['a white counter top with a vase of flowers on top of it'],
#  ['a large white building with a large window'],
#  ['a vase with flowers on a wooden table'],
#  ['a green coffee cup sitting on top of a table'],
#  ['a person holding a cup with a teddy bear on it'],
#  ['a table topped with bowls filled with cupcakes'],
#  ['a table topped with vases filled with flowers'],
#  ['a cup of tea and a spoon on a table'],
#  ['a piece of paper that is on top of a pillow'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a coffee cup with a picture of a bear on it'],
#  ['a dog laying on top of a blanket on a bed'],
#  ['an old black and white photo of a rotten substance'],
#  ['a black and white photo of a piece of cake'],
#  ['a wooden table topped with bowls of food'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a cup of coffee is being poured into a coffee mug'],
#  ['a box filled with lots of chocolate frosted donuts'],
#  ['a person holding a cup in their hand'],
#  ['a wooden table with a vase of flowers on top of it'],
#  ['a piece of paper with a picture of a train on it'],
#  ['a person pouring a liquid into a blender'],
#  ['a table topped with lots of different types of appliances'],
#  ['a traffic light with a street sign on top of it'],
#  ['a number of wine glasses on a table'],
#  ['a motorcycle parked in front of a building'],
#  ['a machine that is inside of a building'],
#  ['a table topped with a bag of doughnuts'],
#  ['a man standing in front of a pot on a stove'],
#  ['a living room filled with lots of furniture'],
#  ['a person sitting on the floor with a cup of coffee'],
#  ['a painting of a woman holding a sign'],
#  ['a store front with a window and a building'],
#  ['a coffee maker on a wooden table'],
#  ['a pot of food on a stove top'],
#  ['a sign that is on the side of a building'],
#  ['a muffin tray filled with muffins on top of a stove'],
#  ['a person pouring a liquid into a blender'],
#  ['a cup of coffee is sitting on a table'],
#  ['a cup of tea in a vase on a table'],
#  ['a cup of tea with a flower in it'],
#  ['a bowl of soup sitting on top of a white table'],
#  ['a piece of cake sitting on top of a toilet'],
#  ['a table topped with a bowl of food and a cell phone'],
#  ['a man and a woman playing a game of ping pong'],
#  ['a table topped with a plate of food and a cup of coffee'],
#  ['a woman in a pink dress sitting on a bed'],
#  ['a glass vase with a flower in it on a table'],
#  ['a kitchen with a stove and a window'],
#  ['a stuffed animal with a cartoon character on it'],
#  ['a bench in front of a building with trees'],
#  ['a blue vase sitting on top of a wooden table'],
#  ['a blue and white plate with a flower on it'],
#  ['a white cup sitting on top of a table'],
#  ['a person holding a cup of coffee in front of a crowd of people'],
#  ['a white cupcake sitting on top of a pile of leaves'],
#  ['a cup of coffee and a plate of food on a table'],
#  ['a piece of cake that is on a table'],
#  ['a pot of food on a stove top'],
#  ['a field filled with lots of green plants'],
#  ['a cupcake with sprinkles on top of it'],
#  ['a pile of brown and white stuff sitting on top of a table'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a collage of photographs showing different types of food'],
#  ['a woman is looking at flowers in a vase'],
#  ['a cup of coffee sitting next to a picture of a cartoon character'],
#  ['a coffee cup sitting on top of a book'],
#  ['a person holding a cup of coffee next to a stuffed animal'],
#  ['a black and white photo of a sign on a white wall'],
#  ['a collage of photos showing different types of food'],
#  ['a coffee cup sitting on top of a book'],
#  ['a dog laying on a bed next to a book'],
#  ['a coffee cup with a picture of a man on it'],
#  ['a coffee cup sitting on top of a white paper'],
#  ['a coffee cup sitting on top of a table'],
#  ['a person holding a spoon in front of a cup'],
#  ['a cup of coffee on top of a wooden table'],
#  ['a traffic light with a street sign on top of it'],
#  ['a kitchen with a large counter top and a large clock on the wall'],
#  ['a statue of a woman standing in front of a fire hydrant'],
#  ['a plate of food on a table with a cup of coffee'],
#  ['a cup of coffee sitting on top of a white plate'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a wooden table topped with plates of food'],
#  ['a cup of coffee sitting on top of a blanket'],
#  ['a coffee cup sitting on top of a table'],
#  ['a table topped with a cup of coffee and a book'],
#  ['a person holding a drink in front of a car'],
#  ['a book and a cup of coffee on a table'],
#  ['a person holding a donut in their hand'],
#  ['a person holding a spoon in front of a bowl of food'],
#  ['a person holding a piece of toast in their hand'],
#  ['a person is spraying something on a fire hydrant'],
#  ['a sign that is on a wall'],
#  ['a man holding a knife in front of a machine'],
#  ['a vase filled with yellow flowers on top of a table'],
#  ['a cup of coffee and a plate of food on a table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a clock hanging from the side of a building'],
#  ['a person holding a spoon in front of a bowl of beans'],
#  ['a chocolate frosted cupcake sitting on top of a white plate'],
#  ['a coffee cup sitting on top of a table next to a flower pot'],
#  ['a cup of coffee next to a piece of cake'],
#  ['a person holding a cup of coffee in their hand'],
#  ['a cup of coffee and a cup of tea on a table'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a table topped with a cup of coffee next to a vase filled with'],
#  ['a man standing next to a woman holding an umbrella'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a piece of bread sitting on top of a paper plate'],
#  ['a box with a bunch of stickers on it'],
#  ['a motorcycle parked in front of a building'],
#  ['a man standing outside of a building looking at a tree'],
#  ['a piece of wood sitting on top of a pile of rocks'],
#  ['a piece of cake sitting on top of a white plate'],
#  ['a large metal door on the side of a building'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a wooden bowl filled with lots of different types of food'],
#  ['a large room with a large clock on the wall'],
#  ['a painting of a man in a suit'],
#  ['a kitchen area with a table and chairs'],
#  ['a painting of a horse on a table in a room'],
#  ['a plate of food on a table with a cup of coffee'],
#  ['a vase filled with flowers sitting on a counter top'],
#  ['a table topped with lots of different types of food'],
#  ['a kitchen with a stove top oven and a counter top'],
#  ['a kitchen counter topped with a blender and other items'],
#  ['a kitchen with a stove top oven and cabinets'],
#  ['a cake with a picture of a dog on it'],
#  ['a plate of food on a table with a cup of coffee'],
#  ['a person holding a spoon in front of a window'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['people riding on a train on a track'],
#  ['a person holding a glass of orange juice on top of a table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a cup of coffee sitting on top of a beach'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a clock hanging from the side of a building'],
#  ['a coffee cup sitting on top of a coffee table'],
#  ['a cupcake sitting on top of a pile of leaves'],
#  ['a laptop computer sitting on top of a wooden table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a person holding a cup of coffee next to a piece of cake'],
#  ['a blender filled with liquid on top of a counter'],
#  ['a cat sitting on top of a blanket next to a book'],
#  ['a large white building with a large window'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a sign on a wall with a bunch of stickers on it'],
#  ['a plate of food on a table with a cup of coffee'],
#  ['a man is holding a cup of coffee in front of a stove'],
#  ['a machine that has a lot of tools on it'],
#  ['a stove top oven sitting on top of a counter'],
#  ['a machine that has a lot of stuff on it'],
#  ['a machine that is sitting on a counter'],
#  ['a table topped with a laptop computer and other items'],
#  ['a kitchen with a shelf filled with dishes'],
#  ['a cup of coffee sitting on top of a machine'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a plate of food on a table with a cup of coffee'],
#  ['a vase filled with flowers sitting on top of a table'],
#  ['a kitchen filled with lots of pots and pans'],
#  ['a kitchen filled with lots of counter space and lots of cabinets'],
#  ['a person is holding a red and white fire hydrant'],
#  ['a patio area with chairs, tables, and umbrellas'],
#  ['a car is parked in front of a tall building'],
#  ['a living room filled with furniture and plants'],
#  ['a large building with a large window on the side of the building'],
#  ['a room with a lot of plants in it'],
#  ['a bathroom with a toilet, sink, and bookshelf'],
#  ['a table topped with plates of food and drinks'],
#  ['a woman is cutting a cake on a table'],
#  ['a building with a large window on the side of it'],
#  ['a cup of coffee sitting on top of a rock'],
#  ['a cup of coffee sitting on top of a table next to a banana'],
#  ['a coffee cup sitting on top of a table'],
#  ['a person holding a cup of coffee in front of a store'],
#  ['a cup of coffee sitting on a table next to a pool of water'],
#  ['two cupcakes sitting on top of a wooden table'],
#  ['a table topped with cakes filled with frosting'],
#  ['a coffee cup with a picture of a cat on it'],
#  ['a birthday cake with a picture of a bear on it'],
#  ['a table topped with lots of different types of food'],
#  ['a book with a clock on top of it'],
#  ['a person sitting on the ground reading a book'],
#  ['a book is sitting on top of a coffee cup'],
#  ['a book that is on top of a table'],
#  ['a white plate topped with a bunch of different types of food'],
#  ['a person laying on a bed with a clock'],
#  ['a table topped with plates of food and a cup of coffee'],
#  ['a laptop computer sitting on top of a wooden table'],
#  ['two cupcakes sitting next to each other on a table'],
#  ['a series of photos showing different types of drinks'],
#  ['a white candle sitting on top of a table next to a book'],
#  ['a pile of apples sitting on top of a table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a kitchen filled with pots and pans'],
#  ['a woman holding a cup of coffee in front of a glass'],
#  ['a painting of a man holding a wine bottle'],
#  ['a bowl of ice cream and a spoon'],
#  ['people sitting around a table in a park'],
#  ['a cup of coffee sitting on top of a white plate'],
#  ['a motorcycle parked on the side of a road'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a pair of scissors sitting on top of a sink'],
#  ['a traffic light with a street sign on top of it'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a coffee cup sitting on top of a table'],
#  ['a woman is cutting a cake on a table'],
#  ['a sign with a picture of a dog on it'],
#  ['a computer monitor sitting on top of a desk'],
#  ['a painting of a cat with a bow on it'],
#  ['a stove top oven sitting on top of a wooden table'],
#  ['a person holding a cup of coffee next to a counter'],
#  ['a cup of coffee sitting on a table next to a book'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a mountain range with trees and mountains'],
#  ['a person holding a cup of coffee in front of a car'],
#  ['a plate of food with eggs, toast and bacon'],
#  ['a woman holding a cup of coffee in front of a window'],
#  ['a table topped with bowls filled with cupcakes'],
#  ['a vase filled with flowers on top of a table'],
#  ['a person holding a drink in front of a blender'],
#  ['a white plate topped with a cup of coffee'],
#  ['a drawing of a penguin on a piece of paper'],
#  ['a man standing in front of a truck with a remote control'],
#  ['a woman in a kitchen with a cup of coffee'],
#  ['a person holding a toothbrush in a kitchen'],
#  ['a man walking down the street with a skateboard'],
#  ['a drawing of a white bird on a black background'],
#  ['a chocolate cupcake sitting on top of a white plate'],
#  ['a cake on a table next to a cup of coffee'],
#  ['a woman standing next to a wall with a sign'],
#  ['a drawing of an apple logo on a white background'],
#  ['a large room with a lot of tables and chairs'],
#  ['a man standing next to a table with a guitar'],
#  ['a metal object sitting on top of a metal pan'],
#  ['a chocolate cupcake sitting on top of a white plate'],
#  ['a cup of coffee sitting on top of a table'],
#  ['two cupcakes with frosting on top of them'],
#  ['a coffee cup sitting on top of a coffee table'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a person holding a cup of coffee'],
#  ['a man sitting at a table with a cup of coffee'],
#  ['a drawing of a knife, scissors, and flowers on a table'],
#  ['a woman walking down a sidewalk with a suitcase'],
#  ['a sign on a beach with people on it'],
#  ['a plate of food with a sandwich and a cup of coffee'],
#  ['a birthday cake with a picture of a dog on it'],
#  ['a bowl of food on a table'],
#  ['a woman with glasses holding up a book'],
#  ['a grocery store sign with a variety of food items on it'],
#  ['a black and white photo of a street sign'],
#  ['a cup of coffee sitting next to a river'],
#  ['a cup of coffee sitting on top of a newspaper'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a bowl of fruit sitting on top of a table next to a window'],
#  ['a wooden table topped with two cakes and a spoon'],
#  ['a vase filled with flowers on top of a table'],
#  ['a wooden table with a piece of cake on top of it'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a white cake with a bow on top of it'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a dining room table topped with plates of food'],
#  ['a bathroom with a toilet, sink, and bookshelf'],
#  ['a bench in front of a building with trees'],
#  ['a large building with a large window on the side of it'],
#  ['a living room filled with lots of furniture'],
#  ['a table topped with a cup of coffee and a muffin'],
#  ['a cup of coffee sitting on top of a white plate'],
#  ['a building that has some tables and chairs in front of it'],
#  ['a building that has graffiti on it'],
#  ['a woman is cutting a cake on a table'],
#  ['a pizza sitting on top of a wooden table'],
#  ['a table topped with plates of food'],
#  ['a table topped with plates filled with food'],
#  ['a woman sitting on a chair in front of a window'],
#  ['a patio area with a bench and a walkway'],
#  ['a building with a sign on the front of it'],
#  ['a building that has graffiti on it'],
#  ['a shop with many different types of pastries on display'],
#  ['a large white building with a clock on the side of it'],
#  ['a man in a kitchen preparing food on a stove'],
#  ['a food stand with food items on display'],
#  ['a large room with a table and chairs in it'],
#  ['a table topped with plates filled with cakes and cupcakes'],
#  ['a large building with a large window on the side of the building'],
#  ['a man standing in front of a large building'],
#  ['a table topped with a vase filled with flowers'],
#  ['a dining area with tables, chairs, tables and umbrellas'],
#  ['a patio area with chairs, tables, and umbrellas'],
#  ['a kitchen with a counter and a counter top'],
#  ['a person holding a cup of coffee on a table'],
#  ['a table topped with cupcakes and a cup of coffee'],
#  ['two men standing next to each other in front of a counter'],
#  ['two pieces of chocolate cake sitting next to each other'],
#  ['a white couch sitting in a room next to a window'],
#  ['a patio area with tables, chairs, and umbrellas'],
#  ['a large kitchen with a large counter top'],
#  ['a man is holding up a piece of cake'],
#  ['a coffee cup sitting on top of a white plate'],
#  ['a coffee cup sitting on top of a table'],
#  ['a cup of coffee sitting next to a cup of coffee'],
#  ['a pot of boiling water on a stove top'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a statue of a man with a clock on top of it'],
#  ['a man in a suit talking on a cell phone'],
#  ['a cup of coffee on a table with a bag of luggage'],
#  ['a plate of food on a wooden table'],
#  ['a bowl of cereal and a spoon on a table'],
#  ['a wooden table topped with plates of food'],
#  ['a person holding a spoon in front of a food processor'],
#  ['a plate of food on a table'],
#  ['a bowl of cereal and a bowl of fruit on a table'],
#  ['a table topped with plates of food next to a cup of coffee'],
#  ['a bowl of food that is on a table'],
#  ['a sign that is on top of a piece of paper'],
#  ['a truck with a dog on the back of it'],
#  ['a close up picture of some food on a label'],
#  ['a blender filled with different types of drinks'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a table topped with a bunch of different types of food'],
#  ['a collage of photos showing different types of computers'],
#  ['a series of photos showing different types of drinks'],
#  ['a wall mounted wall mounted wall mounted wall mounted wall mounted wall mounted wall mounted'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a car is parked in a parking lot next to a fence'],
#  ['a cup of coffee sitting on a table next to a plate of food'],
#  ['two men are playing a game in a kitchen'],
#  ['a coffee cup sitting on top of a counter top'],
#  ['a person holding a vase with a flower in it'],
#  ['a table topped with plates of food and a cup of coffee'],
#  ['a man in a white shirt is holding a blender'],
#  ['a bottle of liquid sitting on top of a wooden table'],
#  ['a blender filled with liquid sitting on top of a table'],
#  ['a person cutting a cake with a knife'],
#  ['a coffee cup sitting on top of a coffee table'],
#  ['a man and woman standing next to each other in front of a store'],
#  ['a sign that reads "don\'t miss a penny"'],
#  ['a food processor with a food inside of it'],
#  ['a collage of photos of various cakes and pastries'],
#  ['a person holding a flower in a vase'],
#  ['a coffee cup with a picture of a cat on it'],
#  ['a table topped with a christmas tree and a cup of coffee'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a coffee cup sitting on top of a table next to a book'],
#  ['a table filled with lots of pots and pans'],
#  ['a woman in a pink dress holding a pink flower in her hand'],
#  ['a pink cupcake with pink flowers on top of it'],
#  ['a teddy bear sitting on a bed next to a christmas tree'],
#  ['a white coffee cup sitting on top of a table'],
#  ['a person holding a stuffed animal in their hand'],
#  ['a glass vase filled with lots of different types of flowers'],
#  ['a green coffee cup sitting on top of a table'],
#  ['a coffee cup with a picture of a bear on it'],
#  ['a pink vase filled with pink flowers next to a pink cup'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a red cup sitting on top of a wooden bench'],
#  ['a table filled with lots of pots and pans'],
#  ['a person holding a cup of coffee next to a cup of coffee'],
#  ['a person holding a clock on top of a kitchen counter'],
#  ['a plate of food on a counter next to a cup of coffee'],
#  ['a person holding a cup of coffee'],
#  ['a shelf filled with different types of cupcakes'],
#  ['a person holding a cup of coffee'],
#  ['a person holding a cup with a spoon'],
#  ['a coffee cup sitting on top of a table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a collection of shoes on a wooden table'],
#  ['a white ceramic cup with a flower on it'],
#  ['a collage of photos of different types of food'],
#  ['a clock on top of a table'],
#  ['a piece of paper with a knife on top of it'],
#  ['a toilet with a basket on top of it'],
#  ['a coffee cup sitting on top of a counter'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a flock of birds flying over a building'],
#  ['a cup of coffee sitting on top of a pillow'],
#  ['a man sitting on a bench in front of a fence'],
#  ['a coffee cup sitting on a table next to a book'],
#  ['a living room filled with furniture and a large window'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a cup of coffee sitting on top of a table next to a plant'],
#  ['a birthday cake with a cartoon character on it'],
#  ['people standing around a table'],
#  ['a wooden table topped with a bunch of apples'],
#  ['a glass of orange juice next to a bowl of ice cream'],
#  ['a man sitting at a table with a cup of coffee'],
#  ['a white plate with a piece of cake on it'],
#  ['a man and a woman are looking at a cell phone'],
#  ['two people dressed in costumes standing next to each other'],
#  ['a table topped with a plate of food and a cup of coffee'],
#  ['a table topped with cakes and cupcakes'],
#  ['a sandwich on a plate with a cup of coffee'],
#  ['a table topped with a cup of coffee and a plate of food'],
#  ['a plate with a cake on top of it'],
#  ['a piece of cake on a plate on a table'],
#  ['a cup of coffee sitting on top of a table next to a book'],
#  ['a piece of cake sitting on top of a white plate'],
#  ['a plate of food on a table'],
#  ['a kitchen counter with a blender and a coffee maker'],
#  ['a kitchen counter with a coffee pot and a microwave'],
#  ['a table topped with a cup of coffee and a muffin'],
#  ['a coffee cup sitting on top of a table'],
#  ['a man holding a sign with a picture of a bear on it'],
#  ['a cup of coffee and a book on a table'],
#  ['a hand holding a package of food'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a kitchen area with a table and chairs'],
#  ['a table topped with plates of food and drinks'],
#  ['a woman in a black shirt and black pants holding a bowl of food'],
#  ['a man is sitting on a wooden bench'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a cup of coffee and a plate of food on a table'],
#  ['plates of food on a table'],
#  ['a woman standing next to a man on a stage'],
#  ['a coffee cup sitting on top of a table'],
#  ['a table topped with plates of food'],
#  ['a person sitting on a couch with a cup of coffee'],
#  ['a doughnut sitting on top of a table next to a cup of coffee'],
#  ['a book and a cup of coffee on a table'],
#  ['a person sitting on a couch with a cup of coffee'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a cup of coffee sitting on top of a book'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a dog sitting on top of a bed next to a book'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a table topped with a plate of food and a candle'],
#  ['a book is sitting on a table with a cup of coffee'],
#  ['a piece of bread on a paper plate on a table'],
#  ['a person laying on a park bench'],
#  ['a person holding a cup of coffee in front of a building'],
#  ['a person holding a cup of coffee in front of a blender'],
#  ['a candle is lit on a table next to a vase of flowers'],
#  ['a living room filled with furniture and a table'],
#  ['a woman walking down a street next to a fire hydrant'],
#  ['a tray of food on a table'],
#  ['a person holding a cup with a cup of coffee in it'],
#  ['a store with a lot of memorabilia on the shelves'],
#  ['a sign that has some graffiti on it'],
#  ['a table that has some vases on it'],
#  ['a woman sitting in a car holding a drink'],
#  ['a black and white photo of a street sign'],
#  ['a man standing in front of a stove in a kitchen'],
#  ['a collage of photos of a woman in a bikini'],
#  ['a cupcake and a cup of coffee on a table'],
#  ['a table topped with flowers and a vase filled with flowers'],
#  ['a person cooking in a pot on a stove'],
#  ['a woman sitting on a couch with a cup of coffee'],
#  ['a sign that reads, "don\'t drink, don\'t eat"'],
#  ['a cup of coffee is sitting on a table'],
#  ['a series of photos showing a car with a sticker on it'],
#  ['a woman holding a baby in the back of a truck'],
#  ['a display of food items on a conveyor belt'],
#  ['a newspaper with a picture of a penguin on it'],
#  ['a cat sitting on top of a coffee cup'],
#  ['a white toilet sitting next to a cup of coffee'],
#  ['a cupcake on a plate next to a cup of coffee'],
#  ['a small vase sitting on top of a white surface'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a person holding a cup of coffee'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a cup of coffee and a cup of tea on a table'],
#  ['a coffee mug and a vase on a table'],
#  ['a teddy bear sitting on top of a table'],
#  ['a bowl of food sitting on top of a table'],
#  ['a collection of books on a table'],
#  ['a table topped with a cup of coffee and a plate of food'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a pink flower shop with pink flowers in front of it'],
#  ['a plate of food on a table'],
#  ['a cup of tea sitting on a table next to a flower pot'],
#  ['a cup of coffee sitting on top of a plant'],
#  ['a cupcake with a flower in it on a table'],
#  ['a vase filled with water next to a fire hydrant'],
#  ['a cup of tea next to a vase of flowers'],
#  ['a cake that is on a table'],
#  ['a cup of coffee sitting on top of a napkin'],
#  ['a plant that is growing out of a pot'],
#  ['a person holding a pair of scissors in their hands'],
#  ['a cup of coffee on a table with a piece of cake on it'],
#  ['a cup of coffee on top of a table'],
#  ['a glass vase sitting on top of a table'],
#  ['a woman and a man posing for a picture'],
#  ['a woman standing in front of a wall with a painting on it'],
#  ['a beach scene with a surfboard on the beach'],
#  ['a person sitting on a table with a book'],
#  ['a black and white photo of a black and white camera'],
#  ['a glass of liquid sitting on top of a table'],
#  ['a person holding a cup filled with ice cream'],
#  ['a cup of tea is sitting on a table'],
#  ['a woman holding a bowl of food in her hands'],
#  ['a person holding a cup of coffee next to a stuffed animal'],
#  ['a person holding a spoon in their hand'],
#  ['a person sitting at a table with a cup of coffee'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a white cup sitting on top of a table'],
#  ['a cup of coffee on a table next to a vase of flowers'],
#  ['a cup of coffee and a pastry on a table'],
#  ['a cup of coffee sitting on top of a white cloth'],
#  ['a table topped with plates filled with cakes'],
#  ['a flower pot sitting on top of a wooden bench'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a person laying on the floor with a pair of scissors'],
#  ['a cup of coffee with a spoon in it'],
#  ['a cup of coffee and a piece of bread on a plate'],
#  ['a white plate topped with a cake on top of a wooden table'],
#  ['a person holding a cup of coffee in their hand'],
#  ['a person holding a cup with a plant in it'],
#  ['a plant that is growing on a table'],
#  ['a vase filled with flowers sitting on a shelf in a kitchen'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a vase filled with flowers on top of a table'],
#  ['a person holding a cup with a flower in it'],
#  ['a garden filled with lots of green plants'],
#  ['a pot filled with lots of different types of plants'],
#  ['a crowd of people standing in front of a sign'],
#  ['a table topped with a cup of coffee next to a book'],
#  ['a sign with a picture of a dog on it'],
#  ['a man and a woman preparing food in a kitchen'],
#  ['a wooden table topped with bowls and bowls of food'],
#  ['a table topped with a plate of food and a cup of coffee'],
#  ['a man holding a camera in his right hand'],
#  ['a table topped with a cup of coffee and a plate of food'],
#  ['a drawing of a person with a knife and a drawing of a person with'],
#  ['a person holding a cup of coffee next to a book'],
#  ['a table topped with plates of donuts and cups of coffee'],
#  ['a table topped with plates of donuts and cups of coffee'],
#  ['a dog sitting on a table next to a plate of donuts'],
#  ['two plates of donuts on a wooden table'],
#  ['a plate of doughnuts and a drink on a table'],
#  ['a cut in half sandwich sitting on top of a cutting board'],
#  ['a person holding a cup filled with ice cream'],
#  ['a box filled with donuts sitting on top of a table'],
#  ['a drawing of a bird on a cake'],
#  ['a coffee cup sitting on top of a wooden bench'],
#  ['a cup of coffee sitting on top of a white plate'],
#  ['a table topped with a bunch of doughnuts'],
#  ['a man and a woman standing in front of a fruit stand'],
#  ['a dining room with a table and chairs'],
#  ['a clock on a wall with christmas decorations on it'],
#  ['a man sitting on a bench in front of a window'],
#  ['a coffee cup with a picture of a woman on it'],
#  ['a book on a table with a plant on top of it'],
#  ['a donut sitting on a table next to a cup of coffee'],
#  ['a coffee cup sitting on top of a bookshelf'],
#  ['a piece of cake sitting on a napkin next to a cup of coffee'],
#  ['a person is reading a book on a bed'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a sign that says, "don\'t stop believing"'],
#  ['a book sitting on top of a bed next to a book'],
#  ['a table topped with a cup of coffee next to a stuffed animal'],
#  ['a man sitting on a bed reading a book'],
#  ['a man holding a picture of himself in front of a painting'],
#  ['a painting of a dog on a table'],
#  ['a painting of a cat sitting on a table next to a book'],
#  ['a book with a picture of a coffee cup on top of it'],
#  ['a painting of a person on a table with a surfboard'],
#  ['a book with a picture of a cat on top of it'],
#  ['a man reading a book on a coffee table'],
#  ['a person holding a cup of coffee next to a sign'],
#  ['a shelf filled with different types of vases'],
#  ['a brown leather purse sitting on top of a table'],
#  ['a person standing in front of a bar with bottles of wine'],
#  ['a person holding a cell phone in their hand'],
#  ['a table with a bag, a mug, and a vase on it'],
#  ['a collage of photos of various food items'],
#  ['a row of vases sitting on top of a table'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a table topped with lots of bottles of alcohol'],
#  ['a cup of coffee sitting on top of a table next to a book'],
#  ['a piece of paper that is on top of a toilet'],
#  ['a cup of coffee and a piece of bread on a table'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a pair of pink and white knitted socks next to a cup of coffee'],
#  ['a laptop computer sitting on top of a wooden table'],
#  ['a woman sitting at a table with a cell phone'],
#  ['a cupcake with a flower in it on a table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a white plate topped with a sandwich and a cup of coffee'],
#  ['a pizza sitting on top of a plate next to a cup of coffee'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a coffee cup sitting on top of a table next to a phone'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a table topped with a cake and a cup of coffee'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a table topped with a bunch of stickers on top of it'],
#  ['a person holding a wii game controller'],
#  ['a man holding a sign with a woman holding a cell phone'],
#  ['a yellow bag sitting on the side of a road'],
#  ['a truck with a sign on the back of it'],
#  ['a sign that says "don\'t drink" on it'],
#  ['a cup of coffee sitting next to a book'],
#  ['a machine that is inside of a building'],
#  ['a machine that has a plant on top of it'],
#  ['a cup of coffee with a picture of a train on it'],
#  ['a polaroid image of a man on a surfboard'],
#  ['an apple in the middle of a piece of wood'],
#  ['two photos of a white vase filled with white frosting'],
#  ['a box that has some food on it'],
#  ['a yellow bag sitting on the side of a road'],
#  ['a black and white photo of a cell phone'],
#  ['a collage of images of different types of electronic devices'],
#  ['a kitchen with a counter top and a sink'],
#  ['a kitchen with a refrigerator and a shelf with books'],
#  ['a kitchen counter top with a stove top oven'],
#  ['a kitchen with pots and pans on the counter'],
#  ['a wooden table topped with pots and pans'],
#  ['a kitchen with a stove top oven and a microwave'],
#  ['a kitchen with pots and pans on the counter'],
#  ['a kitchen filled with pots, pans, and other items'],
#  ['a person standing in a room next to a wall'],
#  ['a suit case filled with lots of luggage'],
#  ['a wooden table topped with lots of different types of items'],
#  ['a man cooking food on top of a table'],
#  ['a box filled with lots of different types of books'],
#  ['a box filled with lots of different types of treats'],
#  ['a box filled with lots of different types of food'],
#  ['a table topped with lots of different types of items'],
#  ['a food truck parked in a grassy area next to a tree'],
#  ['a series of photos showing different types of appliances'],
#  ['a person is spraying a bunch of green beans on a table'],
#  ['a collage of photos of various food items'],
#  ['a person sitting at a table with a laptop'],
#  ['a person pouring a drink into a coffee cup'],
#  ['a man standing in a kitchen preparing food'],
#  ['a cake sitting on top of a stove top'],
#  ['a woman wearing a hat with a flower in it'],
#  ['a person holding a spoon and a cup of coffee'],
#  ['a cup of coffee next to a laptop computer'],
#  ['a cup of coffee is being poured into a coffee mug'],
#  ['a person holding a cup filled with milk'],
#  ['a coffee cup sitting on top of a table'],
#  ['a coffee cup sitting on top of a table next to a window'],
#  ['two cupcakes sitting on top of a counter top'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a painting of a fire hydrant on a table'],
#  ['two cups of coffee sitting on top of a table'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a person holding a cup in front of a coffee table'],
#  ['a person holding a spoon over a cup of ice cream'],
#  ['a man looking out a window of a store'],
#  ['a white plate topped with a dessert on top of a table'],
#  ['a dining room filled with tables and chairs'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a person holding a cup of coffee'],
#  ['a cup of coffee sitting on top of a stove'],
#  ['a motorcycle is parked on the side of the street'],
#  ['people standing around a food truck'],
#  ['a glass vase filled with lots of different types of drinks'],
#  ['a man sitting on a bike next to a garden'],
#  ['a series of photos showing different types of ice cream'],
#  ['a person sitting at a table with a cup of coffee'],
#  ['a large white truck parked in a parking lot'],
#  ['a truck parked on the side of a grassy field'],
#  ['a blue and white truck parked in front of a barn'],
#  ['a person using a spoon to scoop a cup of ice cream'],
#  ['a cake with a flower in it on a table'],
#  ['a glass of orange juice sitting on top of a table'],
#  ['a bottle of orange juice sitting on top of a table'],
#  ['a glass with a flower in it sitting on a table'],
#  ['a person holding a wine glass in front of a red wine bottle'],
#  ['a black bag sitting on top of a white cloth'],
#  ['a cake that is on top of a table'],
#  ['a cat drinking out of a wine glass'],
#  ['a cup of coffee sitting on top of a table'],
#  ['two lit candles sitting next to each other on a brick wall'],
#  ['a stuffed animal is sitting in a basket'],
#  ['a cup of coffee sitting on top of a green field'],
#  ['a person holding a christmas tree'],
#  ['a cup of coffee sitting on top of a white table'],
#  ['a person holding a cup of coffee'],
#  ['a small bird sitting on top of a table'],
#  ['a piece of cake and a cup of coffee on a table'],
#  ['a woman standing next to a blender on a table'],
#  ['a car is parked in front of a parking lot'],
#  ['a person sitting at a table with a cup of coffee'],
#  ['a sign with a picture of a person on it'],
#  ['a man sitting at a table in front of a coffee table'],
#  ['a coffee cup sitting on top of a wooden table'],
#  ['a sign that is on the side of a building'],
#  ['a woman sitting at a table with food'],
#  ['people standing around a table'],
#  ['a sign with a picture of a dog on it'],
#  ['a row of red and white vases sitting on top of each other'],
#  ['a person holding a piece of bread next to a cup of coffee'],
#  ['a wooden box filled with lots of different types of food'],
#  ['a pile of books on top of each other'],
#  ['a table topped with stuffed animals and toys'],
#  ['a table topped with a vase filled with lots of stuff'],
#  ['a living room filled with furniture next to a fire place'],
#  ['a blender and some food on a counter'],
#  ['a building with a sign on the side of it'],
#  ['a kitchen with a stove top oven and a coffee maker'],
#  ['a spoon and a spoonful of powdered sugar on a table'],
#  ['a display of many different types of boxes'],
#  ['a pair of scissors sitting on top of each other'],
#  ['a coffee maker sitting on top of a counter'],
#  ['a yellow and black street sign on a yellow pole'],
#  ['a man in a kitchen preparing food in a kitchen'],
#  ['a cup of coffee sitting next to a book'],
#  ['a collage of photos of a woman and man'],
#  ['a variety of drinks are displayed on a shelf'],
#  ['a table topped with food and a bottle of milk'],
#  ['a bowl of soup with a spoon in it'],
#  ['a bottle of milk and a bottle of ice cream'],
#  ['a cup of coffee next to a bag of cookies'],
#  ['a variety of food items are displayed on a counter'],
#  ['a counter top filled with lots of different types of food'],
#  ['a stuffed animal and a bottle of coke on a table'],
#  ['a coffee mug with a cartoon character on it'],
#  ['a sign on a wall with a picture of a person eating a doughnut'],
#  ['a person holding a sign on a street'],
#  ['a cup of coffee sitting on top of a wooden table'],
#  ['a person holding a cup of coffee'],
#  ['group of people sitting on a beach next to a body of water'],
#  ['a woman standing in front of a truck holding a beer'],
#  ['a book with a picture of a man on it'],
#  ['a bowl of soup and a cup of coffee on a wooden table'],
#  ['a young man preparing food in a kitchen'],
#  ['a woman standing in front of a counter filled with pots and pans'],
#  ['a store front with a table and chairs in front of it'],
#  ['a fence with a bunch of animals inside of it'],
#  ['a woman holding a sign with a picture of a cat on it'],
#  ['an outdoor cafe with tables and chairs'],
#  ['an old photograph of a person standing in front of a clock'],
#  ['a man sitting on a chair with a cup of coffee'],
#  ['a motorcycle parked in front of a restaurant'],
#  ['a little girl standing in front of a grocery store'],
#  ['a woman sitting at a table with a cup of coffee'],
#  ['a woman in a blue dress is sitting on the sidewalk'],
#  ['a cup of coffee sitting on top of a stove top'],
#  ['two cups of coffee on a table'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a woman sitting on a bench with a cup of coffee'],
#  ['a plate with a sandwich and a cup of coffee'],
#  ['a coffee cup sitting on top of a wooden bench'],
#  ['a sign that is on a wooden table'],
#  ['a crowd of people standing next to each other'],
#  ['a person holding a cup of coffee in front of a building'],
#  ['a dog that is sitting in the grass with a cup of coffee'],
#  ['a sign that is on the side of a building'],
#  ['a river flowing through a forest filled with water'],
#  ['a young woman wearing a bikini and holding a pair of scissors'],
#  ['a dog chewing on a piece of cake'],
#  ['a person holding a cup of coffee'],
#  ['a collage of images showing different types of food'],
#  ['a knife sticking out of the side of a kitchen sink'],
#  ['a kitchen counter with a blender on top of it'],
#  ['a fire hydrant with a hose attached to it'],
#  ['a row of stainless steel appliances on a conveyor belt'],
#  ['a cup of coffee on a stove top'],
#  ['a cup of coffee in a bowl on a counter'],
#  ['a collage of photos of a man in a blue shirt'],
#  ['a kitchen with wooden cabinets and a stove top oven'],
#  ['a woman sitting on a toilet in a bathroom'],
#  ['a sandwich and a bowl of soup sit on a table'],
#  ['a person reading a newspaper on a city street'],
#  ['a room with a lot of plants in it'],
#  ['a person holding a spoon and a cup of coffee'],
#  ['a plate of food on a table with a cup of coffee'],
#  ['a person sitting at a table with a plate of food'],
#  ['a table topped with plates of food and drinks'],
#  ['a cup of coffee sitting on a wooden table'],
#  ['a coffee cup sitting on top of a table'],
#  ['a person holding a cup with a coffee cup on top of it'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a man standing in front of a counter in a kitchen'],
#  ['a cup of coffee sitting on a table next to a plant'],
#  ['a cupcake with a picture of a dog on it'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a coffee cup with a picture of a cat on it'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a cup of coffee and a pastry on a wooden bench'],
#  ['a restaurant with tables and chairs in the middle of the room'],
#  ['a large wooden structure with a bench under it'],
#  ['a train station with a train on the tracks'],
#  ['a large white boat sitting in front of a building'],
#  ['a living room filled with furniture and a table'],
#  ['a wooden table with a pot of tea and a cup of coffee'],
#  ['a table with a plate of food and a cup of coffee'],
#  ['a brick building with a fire hydrant in front of it'],
#  ['a sign that is on the side of a building'],
#  ['a person holding a bunch of different types of food'],
#  ['a tree filled with lots of green apples'],
#  ['a car driving down a road next to a forest'],
#  ['a field filled with lots of green plants'],
#  ['a tree filled with lots of green apples'],
#  ['a vase filled with flowers on top of a table'],
#  ['a large bowl filled with lots of red apples'],
#  ['a person holding a cup of coffee next to a doughnut'],
#  ['a cupcake sitting on top of a wooden table'],
#  ['a refrigerator filled with lots of different types of food'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a large piece of chocolate cake sitting on top of a table'],
#  ['a bowl filled with lots of brown stuff on top of a table'],
#  ['a person is using a blender on a table'],
#  ['a large piece of chocolate cake sitting on top of a table'],
#  ['a fire hydrant sitting in front of a church'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a plate of breakfast food and a cup of coffee'],
#  ['a person holding a cup in their hand'],
#  ['a sign with a picture of a dog on it'],
#  ['a person holding a sign on a street'],
#  ['a person holding a cup of coffee next to a doughnut'],
#  ['a plate of food on a wooden table'],
#  ['a piece of cake and a cup of coffee on a plate'],
#  ['a woman sitting at a table with a cup of coffee'],
#  ['a pot of food on a stove top'],
#  ['a cupcake sitting on top of a counter top'],
#  ['a person holding a cup in their hand'],
#  ['a woman sitting at a table with a plate of food'],
#  ['a man holding a cell phone in his hand'],
#  ['a pair of scissors sitting on top of a table'],
#  ['a cup of coffee sitting on top of a white plate'],
#  ['a woman and a man in a room'],
#  ['a blue and white plate with a blue and white bird on it'],
#  ['a black and white photo of a black and white sign'],
#  ['a sign that is on the side of a building'],
#  ['a person sitting at a table with a plate of food'],
#  ['a coffee maker sitting on top of a table'],
#  ['a man sitting at a table with a cup of coffee'],
#  ['a collage of photos showing different types of food'],
#  ['a collage of images of a person on a computer'],
#  ['a painting of a coffee cup with a picture of a dog on it'],
#  ['a cup of coffee sitting on top of a table'],
#  ['a white bowl filled with lots of food'],
#  ['a painting of a cat sitting on top of a stove'],
#  ['a painting of a person holding a cell phone'],
#  ['a bowl filled with donuts on top of a table'],
#  ['a painting of a group of animals on a wall'],
#  ['a glass vase filled with liquid sitting on top of a table'],
#  ['a number of vases on a wooden table'],
#  ['a box sitting on top of a counter top'],
#  ['a person holding a green drink in their hand'],
#  ['a painting of a statue of a man holding a cup'],
#  ['a coffee mug sitting on top of a table'],
#  ['a green vase sitting on top of a table'],
#  ['a tree filled with lots of leaves on top of a building'],
#  ['a person holding a cup with a cartoon character on it'],
#  ['a piece of cake on a plate next to a cup of coffee'],
#  ['a bike parked in front of a store'],
#  ['a table topped with a piece of fruit and a knife'],
#  ['a man and a woman looking at a glass of wine'],
#  ...]

# %%
import pandas as pd

# %%
captions_df = pd.DataFrame()

captions_df['ImageCaptions'] = image_captions

# %%
print(captions_df)
# Out:
#                                           ImageCaptions
# 0     [a living room filled with furniture and a fir...
# 1                  [a building that has graffiti on it]
# 2     [a large building with a clock on the front of...
# 3        [a skateboard with a knife sticking out of it]
# 4     [a large swimming pool in front of a large bui...
# ...                                                 ...
# 1033  [a brick building with a clock on the side of it]
# 1034        [a woman holding a child on top of a couch]
# 1035        [a cup of coffee sitting on top of a table]
# 1036  [a man standing in the middle of a lake with a...
# 1037          [a patio area with a bench and a walkway]
#
# [1038 rows x 1 columns]

# %%
captions_df.to_csv('imgcaptions.csv')

# %%
# !cp imgcaptions.csv "/content/gdrive/MyDrive"
